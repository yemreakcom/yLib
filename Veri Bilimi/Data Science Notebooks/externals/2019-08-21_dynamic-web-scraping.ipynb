# %%
term = '20091'

# %%
from bs4 import BeautifulSoup, NavigableString
from selenium import webdriver
from urllib.parse import urljoin
import numpy as np
import pandas as pd
import re
import sys
import time

# %% [markdown]
# At first, I couldn't figure out why BeautifulSoup couldn't find the content that I was seeing in the HTML. Then I realized it was because the page was dynamic, so it wasn't all loading when I was retrieving it through `urllib`. I found a solution [here](https://stackoverflow.com/questions/17597424/how-to-retrieve-the-values-of-dynamic-html-content-using-python), with more details [here](https://stackoverflow.com/questions/40208051/selenium-using-python-geckodriver-executable-needs-to-be-in-path). I also had to install `geckodriver` using [this](https://anaconda.org/conda-forge/geckodriver).

# %% [markdown]
# # Functions

# %%
def get_term(archive_url):
    '''Used by None. Uses get_subject_list(), get_subject_tables(), and clean_arlt().
    Begins process for scraping whole term. Saves each subject as CSV file.'''
    ge_list = get_subject_list(archive_url)
    df = get_subject_tables(ge_list)
    df = clean_arlt(df)
    filename = 'data/rosters-pre-2014/' + archive_url.rsplit('/', 1)[-1].replace('.html', '') + '.csv'
    df.to_csv(filename, index = False)

def get_subject_list(archive_url):
    '''Used by get_term(). Uses get_dynamic_webpage().
    Receives URL for Schedule of Classes. Returns list of links to each subject.'''
    soup = get_dynamic_webpage(archive_url)
    print(soup)
    page = soup.find('ul', id="programs").find_all('li')
    ge_list = []
    for link in page:
        url = link.find('a')['href']
        full_url = urljoin(archive_url, url)
        ge_list.append(full_url)
    ge_list = sorted(set(ge_list))
    return ge_list

def get_dynamic_webpage(url):
    '''Take URL for Schedule of Classes. Returns soup object.
    Used in get_course_info() and get_subject_list().'''
    try:
        driver.get(url)
        time.sleep(.5)
        html = driver.page_source
        soup = BeautifulSoup(html)
        return soup
    except:
        print('Error in get_dynamic_webpage():', url)

def get_subject_tables(ge_list):
    '''Used by get_term(). Uses get_course_info().
    Receives list of all subjects. Returns DataFrame with all courses for all subjects.'''
    frames = []
    for page in ge_list:
        print('get_subject_tables()', page)
        try:
            df = get_course_info(page)
        except ValueError:
            df = get_course_info(page)
        frames.append(df)
    df = pd.concat(frames, sort = True).reset_index()
    
    return df        
        
def get_course_info(url):
    '''Used by get_subject_tables(). Uses get_course_name().
    Receives URL of course table for subject. Collects data in course table.
    Returns DataFrame of course table.'''
    # Sometimes function doesn't get course info on first try.
    # This makes it retry until it has the course info.
    got_page_info = False
    
    while got_page_info == False:
        soup = get_dynamic_webpage(url)
        table_list = soup.find_all('div', class_ = re.compile('course_info ex.*'))
        
        # If there is no course info, table_list is None. So this returns empty DataFrame.
        if not table_list:
            got_page_info = True
            return pd.DataFrame()

        # Reads each table collected into a list of DataFrames.
        frames = []

        for table in table_list:
            match = table.find('table')
            try:
                df = pd.read_html(str(match), header = 0)[0]
                course_code = table.find('strong').text.replace(':', '').replace(' ', '-')
                course_name = get_course_name(table)
                df['course_code'] = course_code
                df['course_name'] = course_name
                frames.append(df)
            except ValueError:
                pass

        # Asserts that DataFrames have been collected.
        if len(frames) > 0:
            got_page_info = True
            df = pd.concat(frames, sort = True).reset_index()
            return df

def get_course_name(table):
    '''Used by get_course_info(). Uses None.
    Receives table soup for a course. Returns course name.'''
    match = table.find('h3').contents
    for x in match:
        if isinstance(x, NavigableString):
            return x
            break


def clean_arlt(df):
    '''Used by get_term(). Uses None.
    For rows that don\'t have Type (like ARLT), backfills course_name.'''
    for lab, row in df.iterrows():
        if df.loc[lab, 'Type'] is np.nan:
            course_name = df.loc[lab, 'Section']
            df.loc[lab + 1, 'course_name'] = course_name
    df = df.dropna(subset = ['Type'])
    
    return df

# %% [markdown]
# # Begin Scrape

# %%
driver = webdriver.Firefox()
archive_url = 'https://web-app.usc.edu/ws/soc_archive/soc/term_' + term + '.html'
get_term(archive_url)
driver.close()
# Out:
# <html><head>
# <title>Spring 2009 | Schedule of Classes</title>
# <link href="dev/style/A.primary.css.pagespeed.cf.2ga5Yu_DUr.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="dev/style/spring.php?y=2009" media="screen" rel="stylesheet" type="text/css"/>
# <link href="dev/style/A.print.css.pagespeed.cf.SwDQBXsDdx.css" media="print" rel="stylesheet" type="text/css"/>
# <script language="javascript" src="dev/scripts/jquery.pack.js.pagespeed.jm.FMG7C4C0sA.js" type="text/javascript"></script>
# <script language="javascript" type="text/javascript">var term='spring';var deptsrc='api/departments/20091';function showdepartment(dept,deptcode,depttype){return'<li><a href="20091/'+deptcode.toLowerCase()+'.html">'+dept+'</a> ('+deptcode+')</li>';}$(document).ready(function(){$.getJSON(deptsrc,function(json){var programs='';for(i=0;i<json.department.length;i++){if(json.department[i].type!='Y'){programs+=showdepartment(json.department[i].name,json.department[i].code,json.department[i].type);}else{var deptlength=1;programs+='<li>'+json.department[i].name+'<ul>';if(json.department[i].department.length){deptlength=json.department[i].department.length;for(j=0;j<deptlength;j++){programs+=showdepartment(json.department[i].department[j].name,json.department[i].department[j].code,json.department[i].department[j].type);}}else{programs+=showdepartment(json.department[i].department.name,json.department[i].department.code,json.department[i].department.type);}programs+='</ul></li>';}}$('#programs').html(programs);$("#content").fadeIn("slow",function(){$("#content").css("background-image","none");});});$("#uscbar h1").append('<a style="text-indent: 0;padding:0.5rem; display:block; max-width: 380px; font-size: 1rem;line-height:1rem; background: #222; font-family: National, sans-serif; width: auto;height: auto; margin: 0.5rem 0 0 0;"href="https://classes.usc.edu">&laquo; back to the <strong>current Schedule of Classes</strong></a>');$("#uscbar_parent,#uscbar").css({"height":"90px"});});</script>
# </head>
# <body><!--stopindex-->
# <div id="uscbar_parent" style="height: 90px;">
# <div id="uscbar" style="height: 90px;">
# <div id="logo"><a href="http://www.usc.edu">University of Southern California</a></div>
# <h1 class="soctitle"><a href="/ws/soc_archive/soc/">Schedule of Classes Archive</a><a href="https://classes.usc.edu" style="text-indent: 0;padding:0.5rem; display:block; max-width: 380px; font-size: 1rem;line-height:1rem; background: #222; font-family: National, sans-serif; width: auto;height: auto; margin: 0.5rem 0 0 0;">« back to the <strong>current Schedule of Classes</strong></a></h1>
A)</li><li><a href="20091/iom.html">Information and Operations Management</a> (IOM)</li><li><a href="20091/mkt.html">Marketing</a> (MKT)</li><li><a href="20091/mor.html">Management and Organization</a> (MOR)</li></ul></li><li><a href="20091/chem.html">Chemistry</a> (CHEM)</li><li>Cinematic Arts<ul><li><a href="20091/cntv.html">Cinema-Television</a> (CNTV)</li><li><a href="20091/ctan.html">Animation</a> (CTAN)</li><li><a href="20091/ctcs.html">Critical Studies</a> (CTCS)</li><li><a href="20091/ctin.html">Interactive Media</a> (CTIN)</li><li><a href="20091/ctpr.html">Production</a> (CTPR)</li><li><a href="20091/ctwr.html">Writing</a> (CTWR)</li><li><a href="20091/cmpp.html">Motion Picture Producing</a> (CMPP)</li></ul></li><li>Chinese<ul><li><a href="20091/ealc.html">East Asian Languages and Cultures</a> (EALC)</li></ul></li><li>Classics<ul><li><a href="20091/clas.html">Classics</a> (CLAS)</li><li><a href="20091/gr.html">Greek</a> (GR)</li><li><a href="20091/lat.html">Latin</a> (LAT)</li></ul></li><li>Annenberg School for Communication<ul><li><a href="20091/cmgt.html">Communication Management</a> (CMGT)</li><li><a href="20091/comm.html">Communication</a> (COMM)</li><li><a href="20091/jour.html">Journalism</a> (JOUR)</li><li><a href="20091/pubd.html">Public Diplomacy</a> (PUBD)</li></ul></li><li><a href="20091/colt.html">Comparative Literature</a> (COLT)</li><li>Composition, English<ul><li><a href="20091/writ.html">Writing</a> (WRIT)</li></ul></li><li>Czech<ul><li><a href="20091/sll.html">Slavic Languages and Literatures</a> (SLL)</li></ul></li><li>Dentistry<ul><li><a href="20091/dent.html">Dentistry</a> (DENT)</li><li><a href="20091/cby.html">Craniofacial Biology</a> (CBY)</li></ul></li><li>Drama<ul><li><a href="20091/thtr.html">Theatre</a> (THTR)</li></ul></li><li>Earth Sciences<ul><li><a href="20091/geol.html">Geological Sciences</a> (GEOL)</li></ul></li><li><a href="20091/ealc.html">East Asian Languages and Cultures</a> (EALC)</li><li><a href="20091/easc.html">East Asian Studies</a> (EASC)</li><li><a href="20091/econ.html">Economics</a> (ECON)</li><li>Rossier School of Education<ul><li><a href="20091/edco.html">Education Counseling</a> (EDCO)</li><li><a href="20091/ctse.html">Curriculum, Teaching, and Special Education</a> (CTSE)</li><li><a href="20091/edhp.html">Higher and Postsecondary Education</a> (EDHP)</li><li><a href="20091/edpt.html">Educational Psychology and Technology</a> (EDPT)</li><li><a href="20091/educ.html">Education</a> (EDUC)</li>< ...
# <!--stopindex--></div>
# <br clear="all"/>
# </div>
# </div>
# <div id="footer_parent">
# <div id="footer"><div class="pad">
# <div id="feedback"><a href="https://uscweb.wufoo.com/forms/schedule-of-classes-feedback/">Send feedback or report a problem</a></div><!-- feedback -->
# <div id="made_by">Produced by the <a href="http://www.usc.edu/registrar">Office of the Registrar</a></div><!-- made_by -->
# </div>
# <!-- Tracking added 8/31/07-->
# <script src="http://www.google-analytics.com/urchin.js" type="text/javascript"></script>
# <script type="text/javascript">_uacct="UA-827865-5";urchinTracker();</script>
# </div></div></body></html>
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/acct.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/acmd.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/aest.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ahis.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ali.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ame.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/amst.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/anst.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/anth.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/arch.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/arlt.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/aste.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/astr.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/baep.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/bioc.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/bisc.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/bkn.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/bme.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/buad.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/buco.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/cby.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ce.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/che.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/chem.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/clas.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/cmgt.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/cmm.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/cmpp.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/cnb.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/cntv.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/colt.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/comm.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/core.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/csci.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ctan.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ctcs.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ctin.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ctpr.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ctse.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ctwr.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/dent.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ealc.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/easc.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/econ.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/edco.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/edhp.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/edpt.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/educ.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ee.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ene.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/engl.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/engr.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/enst.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/exsc.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/fa.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/fbe.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/fren.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/fsem.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/geog.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/geol.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/germ.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/gero.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/gm.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/gr.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/grsc.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/gsba.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/hebr.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/hist.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/hmgt.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/hp.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/iml.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/inds.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/intd.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/iom.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ir.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ise.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ital.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/itp.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/jour.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/js.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/lat.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/law.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/lbst.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/ling.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/masc.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/math.html
# get_subject_tables() https://web-app.usc.edu/ws/soc_archive/soc/20091/mda.html
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-23ed0ccaad75> in <module>
#       1 driver = webdriver.Firefox()
#       2 archive_url = 'https://web-app.usc.edu/ws/soc_archive/soc/term_' + term + '.html'
# ----> 3 get_term(archive_url)
#       4 driver.close()
#
# <ipython-input-3-5f37cdf31889> in get_term(archive_url)
#       3     Begins process for scraping whole term. Saves each subject as CSV file.'''
#       4     ge_list = get_subject_list(archive_url)
# ----> 5     df = get_subject_tables(ge_list)
#       6     df = clean_arlt(df)
#       7     filename = 'data/rosters-pre-2014/' + archive_url.rsplit('/', 1)[-1].replace('.html', '') + '.csv'
#
# <ipython-input-3-5f37cdf31889> in get_subject_tables(ge_list)
#      41         print('get_subject_tables()', page)
#      42         try:
# ---> 43             df = get_course_info(page)
#      44         except ValueError:
#      45             df = get_course_info(page)
#
# <ipython-input-3-5f37cdf31889> in get_course_info(url)
#      72             match = table.find('table')
#      73             try:
# ---> 74                 df = pd.read_html(str(match), header = 0)[0]
#      75                 course_code = table.find('strong').text.replace(':', '').replace(' ', '-')
#      76                 course_name = get_course_name(table)
#
# ~/anaconda3/envs/capstone/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# ~/anaconda3/envs/capstone/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     892     retained = None
#     893     for flav in flavor:
# --> 894         parser = _parser_dispatch(flav)
#     895         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     896
#
# ~/anaconda3/envs/capstone/lib/python3.7/site-packages/pandas/io/html.py in _parser_dispatch(flavor)
#     838     if flavor in ('bs4', 'html5lib'):
#     839         if not _HAS_HTML5LIB:
# --> 840             raise ImportError("html5lib not found, please install it")
#     841         if not _HAS_BS4:
#     842             raise ImportError(
#
# ImportError: html5lib not found, please install it
